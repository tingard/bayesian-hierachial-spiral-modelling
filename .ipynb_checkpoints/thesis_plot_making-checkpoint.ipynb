# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import numpy as np

# %%
plt.figure(figsize=(8, 8), dpi=100)
ax = plt.gca()
plt.xlim(0, 10)
plt.ylim(0, 10)

# four lines to make the box
shrink = 0.2
plt.arrow(2 + shrink, 2, 6 - 2 * shrink, 0, width=0.1, ec='k', fc='k', length_includes_head=False, head_length=0, head_width=0)
plt.arrow(2 + shrink, 8, 6 - 2 * shrink, 0, width=0.1, ec='k', fc='k', length_includes_head=False, head_length=0, head_width=0)
plt.arrow(8, 2 + shrink, 0, 6 - 2 * shrink, width=0.1, ec='k', fc='k', length_includes_head=False, head_length=0, head_width=0)
plt.arrow(2, 2 + shrink, 0, 6 - 2 * shrink, width=0.1, ec='k', fc='k', length_includes_head=False, head_length=0, head_width=0)

centre_size = 0.6
for i in (-1, 1):
    for j in (-1, 1):
        cx, cy = centre_size * i, centre_size * j
        plt.arrow(5 + cx, 5 + cy, i * (3 - pad) - cx, j * (3 - pad) - cy, width=0.1, ec='k', fc='k', length_includes_head=True)
# plt.arrow(5, 5, 3 - pad, 3 - pad, width=0.1, ec='k', fc='k', length_includes_head=True)
# plt.arrow(5, 5, 3 - pad, 3 - pad, width=0.1, ec='k', fc='k', length_includes_head=True)
# plt.arrow(5, 5, 3 - pad, 3 - pad, width=0.1, ec='k', fc='k', length_includes_head=True)

pad = 0.1
plt.text(2 - pad, 8 + pad, 'Protogalactic\ncollapse', ha='right', va='bottom')
plt.text(5, 8 + pad, 'internal vs external', ha='center', va='bottom')
plt.text(8 + pad, 8 + pad, 'Galaxy mergers,\nRAM-pressure\nstripping of gas', ha='left', va='bottom')
plt.text(2 - pad, 5, 'Fast\nversus\nslow', ha='right', va='center')
plt.text(5, 5 - 0.1, 'star formation,\ngas recycling,\nmetal enrichment,\nenergy feedback via supernovae,\netc.', ha='center', va='center')
plt.text(8 + pad, 5, 'fast\nvs\nslow', ha='left', va='center')
plt.text(2 - pad, 2 - pad, 'Internal\nsecular evolution', ha='right', va='top')
plt.text(5, 2 - pad, 'internal vs external', ha='center', va='top')
plt.text(8 + pad, 2 - pad, 'Environmental\nsecular evolution', ha='left', va='top')
plt.axis('off')
plt.tight_layout()
plt.savefig('Kormendy_secular_evolution_types.pdf', bbox_inches='tight')
